# %%
3 * 5
# Out:
# 15

# %%
import math
math.log(10)
# Out:
# 2.302585092994046

# %% [markdown]
# # This is a heading
#
# I'm going to make a bulleted list
#
# - item 1
# - item 2
# - item 3

# %% [markdown]
# Markdown stuff
#
# ## The exponential distribution has pdf:
# $$f(x) = \lambda e^{-\lambda x}$$
#
# code for a basic command:
#
# `print('hello world')`

# %%
# print function doesn't return a value
x = print(5*6)
# Out:
# 30

# %%
print(x)
# Out:
# None

# %%
4
# Out:
# 4

# %%
None

# %%
In
# Out:
# ['',
#  '3 * 5',
#  'import math\nmath.log(10)',
#  "# print function doesn't return a value\nx = print(5*6)",
#  'print(x)',
#  "get_ipython().run_line_magic('pinfo', 'print')",
#  'None',
#  '4',
#  'None',
#  'In']

# %%
In[1]
# Out:
# '3 * 5'

# %%
Out
# Out:
# {1: 15,
#  2: 2.302585092994046,
#  7: 4,
#  9: ['',
#   '3 * 5',
#   'import math\nmath.log(10)',
#   "# print function doesn't return a value\nx = print(5*6)",
#   'print(x)',
#   "get_ipython().run_line_magic('pinfo', 'print')",
#   'None',
#   '4',
#   'None',
#   'In',
#   'In[1]',
#   'Out'],
#  10: '3 * 5'}

# %%
Out[1]
# Out:
# 15

# %%
Out[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e1b1ede0ba6e> in <module>()
# ----> 1 Out[3]
#
# KeyError: 3

# %%
3*7
# Out:
# 21

# %%
_
# Out:
# 21
